# %%
import scipy.io
import os
import pandas
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plt_lab
import matplotlib.gridspec as gridspec
import obspy
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
heart = pd.read_excel("/Users/ecem/Desktop/seismocardiogram/data/diseased-dataset/Summary_Pub_Deidentified.xlsx")
df = heart.copy().fillna(0)

# %%
df_s = df.loc[:99,['Ejection fraction (%)',
       'Left ventricular end diastolic dimension (mm)', 'IVS (mm)',
       'LVPW (mm)']]
df_s
# Out:
#     Ejection fraction (%)  Left ventricular end diastolic dimension (mm)  \
# 0                    65.5                                           55.0
# 1                    65.4                                           50.0
# 2                    61.9                                           48.0
# 3                    67.5                                           43.0
# 4                    63.6                                           41.0
# ..                    ...                                            ...
# 95                   72.5                                           41.0
# 96                   55.0                                           49.0
# 97                   64.0                                           49.0
# 98                   67.5                                           43.0
# 99                   58.0                                           57.0
#
#     IVS (mm)  LVPW (mm)
# 0       12.0       10.0
# 1       13.0       13.0
# ...

# %%
repeat = [44,
55,
55,
49,
43,
37,
37,
49,
49,
43,
49,
61,
49,
43,
49,
49,
49,
58,
53,
43,
43,
43,
43,
37,
49,
49,
50,
47,
53,
44,
52,
44,
55,
57,
45,
48,
40,
42,
43,
48,
46,
36,
38,
41,
39,
37,
38,
48,
42,
57,
41,
38,
42,
44,
43,
47,
42,
39,
41,
44,
45,
37,
41,
41,
43,
46,
47,
35,
43,
42,
33,
33,
32,
29,
37,
30,
32,
27,
27,
26,
26,
27,
27,
29,
29,
30,
31,
27,
27,
43,
27,
116,
116,
56,
57,
57,
57,
56,
55,
56]

# %%
new_array = np.empty((4414,4), dtype= float)

# %%
array = df_s.to_numpy()

# %%
index = 0
for i, j in enumerate(repeat):
    index += j
    print(' ')
    new_array[index-j:index,:] = array[i]

# %%
new_array[500:520]
# Out:
# array([[66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [66.3, 44. , 11. , 10. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ],
#        [55.7, 64. , 10. ,  9. ]])

# %%
new_array.shape
# Out:
# (4414, 4)

# %%
columns = df_s.columns

# %%
df_new = pd.DataFrame( new_array, columns =columns )

# %%
df_new.iloc[500:520]
# Out:
#      Ejection fraction (%)  Left ventricular end diastolic dimension (mm)  \
# 500                   66.3                                           44.0
# 501                   66.3                                           44.0
# 502                   66.3                                           44.0
# 503                   66.3                                           44.0
# 504                   66.3                                           44.0
# 505                   66.3                                           44.0
# 506                   66.3                                           44.0
# 507                   66.3                                           44.0
# 508                   66.3                                           44.0
# 509                   66.3                                           44.0
# 510                   55.7                                           64.0
# 511                   55.7                                           64.0
# ...

# %%
df_new.to_csv( "/Users/ecem/Desktop/gyrocardiogram/phase2/scg_target_df_10sec.csv")
