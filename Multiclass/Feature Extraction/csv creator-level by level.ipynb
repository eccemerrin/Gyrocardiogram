# %%
import pandas as pd 
import numpy as np

# %%
diseased_path = "/Users/ecem/Desktop/gyrocardiogram/multiclass_data/feature_extr"

# %%
def column_namer(level = 0, lenght = 48):
    x, y, z = [], [], []
    for i in range(lenght):
        x.append("lvl{0}_x{1}".format(level, i))
        y.append("lvl{0}_y{1}".format(level, i))
        z.append("lvl{0}_z{1}".format(level, i))
    
    return x + y + z

# %%
def dataframe_creator(path,  disease = "None", df = pd.DataFrame(), level = 0):
    values, dis  = [], [] 
    dis.append(disease)
    array = np.load(path + "/" + disease + "_lvl_{}.npy".format(level), allow_pickle = True)
    columns = column_namer(level = level, lenght = array.shape[2])
    
    for i in range(array.shape[1]):
        values.append(array[0][i].tolist()+ array[1][i].tolist()+ array[2][i].tolist() + dis) 

        medium = pd.DataFrame([values[i]], columns = columns + ["disease"])
        
        df = pd.concat([df, medium], axis = 0, ignore_index=True)
        
    
    return df

# %% [markdown]
# ### Level 0

# %%
df_lvl0 = dataframe_creator(diseased_path, 'four-disease',  level =0 )

# %%
df_lvl0
# Out:
#        lvl0_x0   lvl0_x1   lvl0_x2   lvl0_x3   lvl0_x4   lvl0_x5   lvl0_x6  \
# 0     5.467409  6.475835  5.978283  3.808917  0.237247  2.721316  4.305257
# 1     5.236702  6.239316  5.715105  3.478843 -0.533578  3.551597  2.415447
# 2     1.643137  2.369920  2.226041  1.124100  0.842080  0.485410  1.298561
# 3     2.227607  1.971363  1.942300  2.027811  1.171732 -2.275889  1.920701
# 4     0.532122 -0.243520 -0.251224  0.365505 -1.649213  3.254912  2.556652
# ...        ...       ...       ...       ...       ...       ...       ...
# 2101 -2.280562 -1.782608 -1.666618 -1.441902  2.076644  1.893703  0.506681
# 2102 -2.258214 -2.388813 -2.246703 -1.486669  0.567195  3.433898  0.816254
# 2103 -0.964271 -1.250291 -1.113007 -0.418786  0.643989 -0.723275 -3.191579
# 2104 -0.530285 -0.757646 -0.539483  0.182897  2.121376  0.512988  0.798943
# 2105 -1.562304 -1.504773 -1.582889 -1.860618 -2.734726 -1.826781 -1.689338
#
#        lvl0_x7   lvl0_x8   lvl0_x9  ...  lvl0_z39  lvl0_z40  lvl0_z41  \
# 0     4.656622  7.142733  7.058521  ...  0.890555  3.398055  1.683546
# 1     1.381255  0.901457 -1.644835  ...  0.275623  2.596833  2.536577
# 2     2.625077  2.121489 -1.080766  ...  2.027973  3.626036  3.209004
# 3     0.266703  1.312790  1.118698  ...  2.955133  2.162382  0.332423
# 4     1.139769  0.046310  2.861301  ...  1.183014  3.117626  2.255243
# ...        ...       ...       ...  ...       ...       ...       ...
# 2101  0.157219 -0.688401 -2.736367  ...  0.474143 -0.055524 -0.206653
# 2102 -0.032946  0.270713 -0.241465  ... -0.871119 -0.074291  0.619744
# 2103 -1.020906 -0.652156  3.246363  ...  0.074332  0.130729 -0.542842
# 2104  0.010890 -0.693388 -3.062880  ...  0.335085 -0.118549  0.329681
# 2105  3.385016  2.512326  0.848188  ... -0.001185 -0.000101 -0.000212
#
#       lvl0_z42  lvl0_z43  lvl0_z44  lvl0_z45  lvl0_z46  lvl0_z47       disease
# 0     1.953521  1.884336  3.337115  2.892143  2.902176  3.054463  four-disease
# 1     1.353387  1.348864  1.567292  1.382271  1.446645  1.549479  four-disease
# 2    -0.134956  1.253442  0.246203  0.389060  0.444405  0.397022  four-disease
# 3     2.512636  1.868316  1.286057  1.486791  1.487241  1.411369  four-disease
# 4     1.461551  1.337653  3.555023  3.041664  2.981505  3.120505  four-disease
# ...        ...       ...       ...       ...       ...       ...           ...
# 2101 -0.175639 -0.956635 -0.977654 -0.954696 -0.949013 -0.922854  four-disease
# 2102  0.322873  0.318044 -0.032990  0.007116  0.036962  0.042782  four-disease
# 2103 -0.112488 -0.638902 -1.010991 -0.917975 -0.897326 -0.906142  four-disease
# 2104 -0.059718  0.213193  0.465949  0.449462  0.418689  0.400873  four-disease
# 2105 -0.000011 -0.000095 -0.000190 -0.000175 -0.000168 -0.000166  four-disease
#
# [2106 rows x 145 columns]

# %%
df_lvl0.to_csv(diseased_path + '/wavelet_lvl0.csv')
